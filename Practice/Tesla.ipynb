# %%
# Install pandas datareader

#!pip install pandas-datareader

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#df_tesal = pdr.get_data_yahoo('TSLA') # you run also this type of code

# %%
#!pip install yfinance

# %%
import yfinance as yf

# Download Tesla (TSLA) data
# Use yf.download('TSLA') to fetch historical stock data for Tesla (TSLA).
data = yf.download('TSLA')
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-07-23  253.600006  255.759995  245.630005  246.380005  246.380005
# 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
#
#                Volume
# Date
# ...

# %%
data.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
# xlimit and ylimit
data['High'].plot(xlim = ['2020-01-01' , '2021-09-01'],ylim = [0,400],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
# coloring

data['High'].plot(xlim = ['2020-01-01' , '2021-09-01'],ylim = [0,400],figsize=(12,4),ls = '--',c = 'green')
# Out:
# <Axes: xlabel='Date'>

# %%
data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-07-16', '2024-07-17', '2024-07-18', '2024-07-19',
#                '2024-07-22', '2024-07-23', '2024-07-24', '2024-07-25',
#                '2024-07-26', '2024-07-29'],
#               dtype='datetime64[ns]', name='Date', length=3544, freq=None)

# %%
index= data.loc['2020-01-01' : '2021-09-01'].index
share_open = data.loc['2020-01-01' : '2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
figure,axis = plt.subplots(figsize=(12,4))
plt.tight_layout()

# Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
## Date Time Index

data = data.reset_index()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3544 entries, 0 to 3543
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3544 non-null   datetime64[ns]
#  1   Open       3544 non-null   float64
#  2   High       3544 non-null   float64
#  3   Low        3544 non-null   float64
#  4   Close      3544 non-null   float64
#  5   Adj Close  3544 non-null   float64
#  6   Volume     3544 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 193.9 KB

# %%
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3539 2024-07-23  253.600006  255.759995  245.630005  246.380005  246.380005
# 3540 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 3541 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 3542 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 3543 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
data = data.set_index('Date',drop = True)

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-07-23  253.600006  255.759995  245.630005  246.380005  246.380005
# 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
## DateTime

from datetime import datetime

# %%
datetime(2024,7,17,0,0)
# Out:
# datetime.datetime(2024, 7, 17, 0, 0)

# %%
# Show the current date and time
datetime.now()
# Out:
# datetime.datetime(2024, 7, 30, 9, 49, 52, 800338)

# %%
# If you want to find out how much time a function to exceuted  
# eg :-
def add_num(num1,num2):
   return num1+num2
    
start_time  = datetime.now()
num1 = 20
num2  = 30
for i in [1,2,3,4,5]:
    
  add_num(num1,num2)
end_time = datetime.now()
print(end_time - start_time)
# Out:
# 0:00:00.001007

# %%
date = datetime(2024,7,17)

# %%
date
# Out:
# datetime.datetime(2024, 7, 17, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2024, 7, 17)

# %%
date.day
# Out:
# 17

# %%
date.weekday()
# Out:
# 2

# %%
date.year
# Out:
# 2024

# %% [markdown]
# ## Time Resampling
# https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
# Here are some common frequency aliases used in pandas:

# 'A' : Annual end frequency (yearly)
# 'M' : Monthly
# 'QS' : Quarterly
# 'W' : Weekly
# 'D' : Daily
# 'H' : Hourly
# 'T' : Minute
# 'S' : Second

# %%
data.resample(rule = 'A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
data.resample(rule = 'A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
#  year and frequency 
data.resample(rule = 'A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## Quaterly start frequency
data.resample(rule = 'QS').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.266667    1.666667    1.169333    1.588667    1.588667
# 2010-07-01    1.076000    1.108667    0.998667    1.053333    1.053333
# 2010-10-01    1.344000    1.352000    1.333333    1.336667    1.336667
# 2011-01-01    1.452000    1.484667    1.407333    1.455333    1.455333
# 2011-04-01    1.658000    1.680667    1.613333    1.643333    1.643333
# 2011-07-01    1.462000    1.540667    1.433333    1.463333    1.463333
# 2011-10-01    1.552667    1.621333    1.528667    1.577333    1.577333
# 2012-01-01    1.774667    1.792000    1.509333    1.519333    1.519333
# 2012-04-01    1.838667    1.892667    1.788667    1.837333    1.837333
# 2012-07-01    1.789333    1.790000    1.701333    1.740000    1.740000
# 2012-10-01    1.825333    1.853333    1.790667    1.822000    1.822000
# 2013-01-01    2.205333    2.225333    2.140667    2.194000    2.194000
# ...

# %%
data.resample(rule = 'QS').min()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## Business  end frequency
data.resample(rule = 'BA').mean()['Open'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
data.resample(rule = 'BA').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-30    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-30    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-29   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
data.resample(rule = 'BQS').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.266667    1.666667    1.169333    1.588667    1.588667
# 2010-07-01    1.076000    1.108667    0.998667    1.053333    1.053333
# 2010-10-01    1.344000    1.352000    1.333333    1.336667    1.336667
# 2011-01-03    1.452000    1.484667    1.407333    1.455333    1.455333
# 2011-04-01    1.658000    1.680667    1.613333    1.643333    1.643333
# 2011-07-01    1.462000    1.540667    1.433333    1.463333    1.463333
# 2011-10-03    1.552667    1.621333    1.528667    1.577333    1.577333
# 2012-01-02    1.774667    1.792000    1.509333    1.519333    1.519333
# 2012-04-02    1.838667    1.892667    1.788667    1.837333    1.837333
# 2012-07-02    1.789333    1.790000    1.701333    1.740000    1.740000
# 2012-10-01    1.825333    1.853333    1.790667    1.822000    1.822000
# 2013-01-01    2.205333    2.225333    2.140667    2.194000    2.194000
# ...

# %%
data.resample(rule = 'M').max()['Open'].plot(xlim=['2020-01-01','2024-01-01'],kind = 'bar',figsize= (30,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Simple Moving Average
# The Simple Moving Average (SMA) is primarily used in financial markets, economics, supply chain management,
# quality control, and meteorology because it is simple to calculate,
# helps identify and confirm trends, reduces noise, and is versatile across various applications.

# %%
# rolling(10): This applies a rolling window of size 10 to the 'High' column.
# A rolling window is a fixed-size window that moves over the data, performing a calculation at each position
data['High'].rolling(10).mean()
# Out:
# Date
# 2010-06-29           NaN
# 2010-06-30           NaN
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06           NaN
#                  ...
# 2024-07-23    258.867001
# 2024-07-24    254.707002
# 2024-07-25    250.207002
# 2024-07-26    247.251003
# 2024-07-29    244.118002
# Name: High, Length: 3544, dtype: float64

# %%
data['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    1.421333
# 2010-07-14    1.389000
# 2010-07-15    1.329533
# 2010-07-16    1.298733
# 2010-07-19    1.293067
# 2010-07-20    1.305400
# 2010-07-21    1.333867
# 2010-07-22    1.358733
# 2010-07-23    1.383133
# 2010-07-26    1.406000
# 2010-07-27    1.422933
# Name: High, dtype: float64

# %%
data['Open:30 days rolling'] = data['Open'].rolling(30).mean()

# %%
data.head(31)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
data[['Open','Open:30 days rolling']].plot(xlim=['2021-01-01','2024-01-01'],figsize = (12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
data['Open: 10 days rolling'] = data['Open'].rolling(window = 10, min_periods=1).mean()
data['Open: 30 days rolling'] = data['Open'].rolling(window = 30, min_periods=1).mean()
data['Open: 50 days rolling'] = data['Open'].rolling(window = 50, min_periods=1).mean()

# %%
data[['Open','Open: 10 days rolling','Open: 30 days rolling','Open: 50 days rolling']].plot(xlim = ['2022-01-01' ,'2024-07-01'],figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Disadvantages of Simple Moving Average (SMA):
#
# 1. Lagging Indicator: Slow to react to recent price changes.
# 2. Sensitivity to Outliers: Affected by sudden, short-term spikes or drops.
# 3. Equal Weighting: Assigns equal importance to all data points, which may not be ideal.
# 4. Fixed Window: Arbitrary choice of window size may not adapt to different conditions.
# 5. No Predictive Power: Only smooths past data without predicting future trends.

# %% [markdown]
# ### Expanding
# #### Cummulative Moving Avearge
# Expanding in Time Series refers to a technique used to calculate expanding statistics,
# where the window size increases with each data point, encompassing all previous observations.
# Unlike fixed-window methods like the Simple Moving Average (SMA),
# expanding methods take into account all data points up to the current point in time.

# %%
data['Open'].expanding().mean().plot(figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Disadvantages of Expanding in Time Series
# 1. Lagging Nature: Similar to SMA, expanding calculations can lag, especially when changes occur rapidly.
# 2. Computationally Intensive: As the number of data points increases, the computational load also increases,
#    which can be a drawback for very large datasets.

# %% [markdown]
# ### Exponential Moving Avg
# Exponential Moving Average (EMA) is a type of moving average that gives more weight to recent data points, making it more sensitive to recent price movements. It's commonly used in technical analysis to smooth out price fluctuations and identify trends.
#
# EMA = (Close * alpha) + (Previous EMA * (1 - alpha))

# %%
# alpha = 0.1 means that the EWM function will give more weight to recent data points
# adjust=False means that the EWM function will not adjust the weights.

data['EMA_0.1'] = data['Open'].ewm(alpha = 0.1, adjust=False).mean()

# %%
data[['Open','EMA_0.1']].plot(xlim = ['2023-01-01' ,'2024-07-01'],figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
data['EMA_0.3'] = data['Open'].ewm(alpha = 0.3, adjust=False).mean()

# %%
data[['Open','EMA_0.1','EMA_0.3']].plot(xlim = ['2023-01-01' ,'2024-07-01'],figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
data['EMA_5days'] = data['Open'].ewm(span=5).mean()

# %%
data[['Open','EMA_0.1','EMA_5days']].plot(xlim = ['2023-01-01' ,'2024-07-01'],figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>
